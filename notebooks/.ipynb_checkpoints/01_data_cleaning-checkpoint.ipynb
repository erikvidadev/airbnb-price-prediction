# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## Why is it important?
# Poorly cleaned data leads to misleading conclusions and bad models.

# %% [markdown]
# ## What should it contain?
#
# - Loading data
# - Basic information (.shape, .info(), .describe())
# - Handling missing values (e.g., filling in, deleting)
# - Searching for and removing duplicates
# - Checking types (e.g., dates → datetime, prices → float)
# - Filtering out outliers (e.g., $10,000/night on Airbnb is unrealistic)
# - Standardization (e.g., currencies, formats)

# %% [markdown]
# ### Imports

# %%
import os
import sys

import pandas as pd
import numpy as np
from dotenv import load_dotenv


project_root = "/Users/erikvida/PycharmProjects/airbnb-price-prediction"
if project_root not in sys.path:
    sys.path.append(project_root)

from src.db_connection import DatabaseConfig, DatabaseConnection


dotenv_path = "/Users/erikvida/PycharmProjects/airbnb-price-prediction/.env"
load_dotenv(dotenv_path)
# Out:
# True

# %% [markdown]
# ### 1.0 Loading data

# %%
amsterdams_airbnbs_raw_data = pd.read_csv("../data/raw/amsterdam_airbnbs_data.csv")
df = amsterdams_airbnbs_raw_data
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  27886  https://www.airbnb.com/rooms/27886  20250609011745   2025-06-17
# 1  28871  https://www.airbnb.com/rooms/28871  20250609011745   2025-06-17
# 2  29051  https://www.airbnb.com/rooms/29051  20250609011745   2025-06-17
# 3  44391  https://www.airbnb.com/rooms/44391  20250609011745   2025-06-17
# 4  47061  https://www.airbnb.com/rooms/47061  20250609011745   2025-06-17
#
#             source                                               name  \
# 0      city scrape  Romantic, stylish B&B houseboat in canal district
# 1      city scrape                            Comfortable double room
# 2      city scrape                   Comfortable single / double room
# 3  previous scrape    Quiet 2-bedroom Amsterdam city centre apartment
# 4      city scrape                   Charming apartment in old centre
#
#                                          description  \
# 0  Stylish and romantic houseboat on fantastic hi...
# 1          Basic bedroom in the center of Amsterdam.
# 2  This room can also be rented as a single or a ...
# 3  Guests greatly appreciate the unique location ...
# 4  A beautiful, quiet apartment in the center of ...
#
#                                neighborhood_overview  \
# 0         Central, quiet, safe, clean and beautiful.
# 1       Flower market , Leidseplein , Rembrantsplein
# 2  the street is quite lively especially on weeke...
# 3  The appartment is located in the city centre. ...
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/02c2da9d-660e...    97647  ...
# 1  https://a0.muscache.com/pictures/160889/362340...   124245  ...
# 2  https://a0.muscache.com/pictures/162009/bd6be2...   124245  ...
# 3  https://a0.muscache.com/pictures/97741545/3900...   194779  ...
# 4  https://a0.muscache.com/pictures/268343/a08ce2...   211696  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.92                   4.90                4.78
# 1                        4.94                   4.94                4.84
# 2                        4.92                   4.87                4.79
# 3                        4.90                   4.68                4.50
# 4                        4.90                   4.85                4.63
#
#                     license instant_bookable calculated_host_listings_count  \
# 0  0363 974D 4986 7411 88D8                f                              1
# 1  0363 607B EA74 0BD8 2F6F                f                              2
# 2  0363 607B EA74 0BD8 2F6F                f                              2
# 3  0363 E76E F06A C1DD 172C                f                              1
# 4  0363 1266 8C04 4133 E6AC                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            2
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.85
# 1                                           0              3.93
# 2                                           0              4.74
# 3                                           0              0.23
# 4                                           0              1.13
#
# [5 rows x 79 columns]

# %% [markdown]
# ### 2.0 Basic informations

# %% [markdown]
# #### 2.1 Shape

# %%
num_rows, num_columns = df.shape
print(f" Rows: {num_rows}, Columns: {num_columns}")
# Out:
#  Rows: 10168, Columns: 79

# %% [markdown]
# #### 2.2 Info - Data type of the differnt culomns

# %%
print("\n Data Types:")
df.info()
# Out:
#  Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10168 entries, 0 to 10167
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            10168 non-null  int64
#  1   listing_url                                   10168 non-null  object
#  2   scrape_id                                     10168 non-null  int64
#  3   last_scraped                                  10168 non-null  object
#  4   source                                        10168 non-null  object
#  5   name                                          10168 non-null  object
#  6   description                                   9859 non-null   object
#  7   neighborhood_overview                         5258 non-null   object
#  8   picture_url                                   10168 non-null  object
#  9   host_id                                       10168 non-null  int64
#  10  host_url                                      10168 non-null  object
#  11  host_name                                     10164 non-null  object
#  12  host_since                                    10164 non-null  object
#  13  host_location                                 9024 non-null   object
#  14  host_about                                    5372 non-null   object
#  15  host_response_time                            6640 non-null   object
#  16  host_response_rate                            6640 non-null   object
#  17  host_acceptance_rate                          7937 non-null   object
#  18  host_is_superhost                             10069 non-null  object
#  19  host_thumbnail_url                            10164 non-null  object
#  20  host_picture_url                              10164 non-null  object
#  21  host_neighbourhood                            2814 non-null   object
#  22  host_listings_count                           10164 non-null  float64
#  23  host_total_listings_count                     10164 non-null  float64
#  24  host_verifications                            10164 non-null  object
#  25  host_has_profile_pic                          10164 non-null  object
#  26  host_identity_verified                        10164 non-null  object
#  27  neighbourhood                                 5258 non-null   object
#  28  neighbourhood_cleansed                        10168 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      10168 non-null  float64
#  31  longitude                                     10168 non-null  float64
#  32  property_type                                 10168 non-null  object
#  33  room_type                                     10168 non-null  object
#  34  accommodates                                  10168 non-null  int64
#  35  bathrooms                                     6377 non-null   float64
#  36  bathrooms_text                                10162 non-null  object
#  37  bedrooms                                      9874 non-null   float64
#  38  beds                                          6341 non-null   float64
#  39  amenities                                     10168 non-null  object
#  40  price                                         6321 non-null   object
#  41  minimum_nights                                10168 non-null  int64
#  42  maximum_nights                                10168 non-null  int64
#  43  minimum_minimum_nights                        10168 non-null  int64
#  44  maximum_minimum_nights                        10168 non-null  int64
#  45  minimum_maximum_nights                        10168 non-null  int64
#  46  maximum_maximum_nights                        10168 non-null  int64
#  47  minimum_nights_avg_ntm                        10168 non-null  float64
#  48  maximum_nights_avg_ntm                        10168 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              9849 non-null   object
#  51  availability_30                               10168 non-null  int64
#  52  availability_60                               10168 non-null  int64
#  53  availability_90                               10168 non-null  int64
#  54  availability_365                              10168 non-null  int64
#  55  calendar_last_scraped                         10168 non-null  object
#  56  number_of_reviews                             10168 non-null  int64
#  57  number_of_reviews_ltm                         10168 non-null  int64
#  58  number_of_reviews_l30d                        10168 non-null  int64
#  59  availability_eoy                              10168 non-null  int64
#  60  number_of_reviews_ly                          10168 non-null  int64
#  61  estimated_occupancy_l365d                     10168 non-null  int64
#  62  estimated_revenue_l365d                       6321 non-null   float64
#  63  first_review                                  9198 non-null   object
#  64  last_review                                   9198 non-null   object
#  65  review_scores_rating                          9198 non-null   float64
#  66  review_scores_accuracy                        9198 non-null   float64
#  67  review_scores_cleanliness                     9197 non-null   float64
#  68  review_scores_checkin                         9198 non-null   float64
#  69  review_scores_communication                   9198 non-null   float64
#  70  review_scores_location                        9198 non-null   float64
#  71  review_scores_value                           9198 non-null   float64
#  72  license                                       10062 non-null  object
#  73  instant_bookable                              10168 non-null  object
#  74  calculated_host_listings_count                10168 non-null  int64
#  75  calculated_host_listings_count_entire_homes   10168 non-null  int64
#  76  calculated_host_listings_count_private_rooms  10168 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   10168 non-null  int64
#  78  reviews_per_month                             9198 non-null   float64
# dtypes: float64(20), int64(24), object(35)
# memory usage: 6.1+ MB

# %% [markdown]
# #### 2.3 Descriptive statistics

# %%
print("\n Descriptive Statistics:")
df.describe().T
# Out:
#  Descriptive Statistics:
#                                                 count          mean  \
# id                                            10168.0  5.495778e+17
# scrape_id                                     10168.0  2.025061e+13
# host_id                                       10168.0  1.302961e+08
# host_listings_count                           10164.0  3.524105e+00
# host_total_listings_count                     10164.0  5.403680e+00
# neighbourhood_group_cleansed                      0.0           NaN
# latitude                                      10168.0  5.236666e+01
# longitude                                     10168.0  4.889542e+00
# accommodates                                  10168.0  2.926928e+00
# bathrooms                                      6377.0  1.250039e+00
# bedrooms                                       9874.0  1.557322e+00
# beds                                           6341.0  1.841981e+00
# minimum_nights                                10168.0  4.129622e+00
# maximum_nights                                10168.0  2.897820e+02
# minimum_minimum_nights                        10168.0  3.710366e+00
# maximum_minimum_nights                        10168.0  4.758163e+00
# minimum_maximum_nights                        10168.0  4.227708e+05
# maximum_maximum_nights                        10168.0  4.227936e+05
# minimum_nights_avg_ntm                        10168.0  4.151465e+00
# maximum_nights_avg_ntm                        10168.0  4.227842e+05
# calendar_updated                                  0.0           NaN
# availability_30                               10168.0  5.806058e+00
# availability_60                               10168.0  1.415647e+01
# availability_90                               10168.0  2.218942e+01
# availability_365                              10168.0  9.103501e+01
# number_of_reviews                             10168.0  4.756884e+01
# number_of_reviews_ltm                         10168.0  8.967840e+00
# number_of_reviews_l30d                        10168.0  7.596381e-01
# availability_eoy                              10168.0  4.994955e+01
# number_of_reviews_ly                          10168.0  8.634048e+00
# estimated_occupancy_l365d                     10168.0  5.116552e+01
# estimated_revenue_l365d                        6321.0  1.628915e+04
# review_scores_rating                           9198.0  4.844651e+00
# review_scores_accuracy                         9198.0  4.855278e+00
# review_scores_cleanliness                      9197.0  4.779614e+00
# review_scores_checkin                          9198.0  4.893529e+00
# review_scores_communication                    9198.0  4.907673e+00
# review_scores_location                         9198.0  4.813358e+00
# review_scores_value                            9198.0  4.655034e+00
# calculated_host_listings_count                10168.0  1.852085e+00
# calculated_host_listings_count_entire_homes   10168.0  1.208694e+00
# calculated_host_listings_count_private_rooms  10168.0  5.751377e-01
# calculated_host_listings_count_shared_rooms   10168.0  3.373328e-02
# reviews_per_month                              9198.0  9.822157e-01
#
#                                                        std           min  \
# id                                            5.381949e+17  2.788600e+04
# scrape_id                                     0.000000e+00  2.025061e+13
# host_id                                       1.737325e+08  1.662000e+03
# host_listings_count                           3.057866e+01  1.000000e+00
# host_total_listings_count                     5.506787e+01  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      1.712460e-02  5.229028e+01
# longitude                                     3.524221e-02  4.755870e+00
# accommodates                                  1.292811e+00  1.000000e+00
# bathrooms                                     5.376453e-01  0.000000e+00
# bedrooms                                      8.936146e-01  0.000000e+00
# beds                                          1.625684e+00  0.000000e+00
# minimum_nights                                1.726756e+01  1.000000e+00
# maximum_nights                                3.933918e+02  1.000000e+00
# minimum_minimum_nights                        1.616172e+01  1.000000e+00
# maximum_minimum_nights                        1.886966e+01  1.000000e+00
# minimum_maximum_nights                        3.011658e+07  1.000000e+00
# maximum_maximum_nights                        3.011658e+07  1.000000e+00
# minimum_nights_avg_ntm                        1.640335e+01  1.000000e+00
# maximum_nights_avg_ntm                        3.011658e+07  1.000000e+00
# calendar_updated                                       NaN           NaN
# availability_30                               8.761619e+00  0.000000e+00
# availability_60                               1.861863e+01  0.000000e+00
# availability_90                               2.868551e+01  0.000000e+00
# availability_365                              1.160660e+02  0.000000e+00
# number_of_reviews                             1.281138e+02  0.000000e+00
# number_of_reviews_ltm                         2.507633e+01  0.000000e+00
# number_of_reviews_l30d                        2.101968e+00  0.000000e+00
# availability_eoy                              6.449601e+01  0.000000e+00
# number_of_reviews_ly                          2.446415e+01  0.000000e+00
# estimated_occupancy_l365d                     7.767660e+01  0.000000e+00
# estimated_revenue_l365d                       4.915380e+04  0.000000e+00
# review_scores_rating                          2.507588e-01  1.000000e+00
# review_scores_accuracy                        2.427312e-01  1.000000e+00
# review_scores_cleanliness                     3.114479e-01  1.000000e+00
# review_scores_checkin                         2.136636e-01  1.000000e+00
# review_scores_communication                   2.138484e-01  1.000000e+00
# review_scores_location                        2.370858e-01  2.000000e+00
# review_scores_value                           3.165698e-01  1.000000e+00
# calculated_host_listings_count                3.343481e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   2.512860e+00  0.000000e+00
# calculated_host_listings_count_private_rooms  1.770011e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   4.739117e-01  0.000000e+00
# reviews_per_month                             2.112976e+00  1.000000e-02
#
#                                                        25%           50%  \
# id                                            2.475968e+07  6.545968e+17
# scrape_id                                     2.025061e+13  2.025061e+13
# host_id                                       1.269467e+07  4.442366e+07
# host_listings_count                           1.000000e+00  1.000000e+00
# host_total_listings_count                     1.000000e+00  1.000000e+00
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.235567e+01  5.236552e+01
# longitude                                     4.864550e+00  4.887365e+00
# accommodates                                  2.000000e+00  2.000000e+00
# bathrooms                                     1.000000e+00  1.000000e+00
# bedrooms                                      1.000000e+00  1.000000e+00
# beds                                          1.000000e+00  1.000000e+00
# minimum_nights                                2.000000e+00  3.000000e+00
# maximum_nights                                2.000000e+01  3.000000e+01
# minimum_minimum_nights                        2.000000e+00  2.000000e+00
# maximum_minimum_nights                        2.000000e+00  3.000000e+00
# minimum_maximum_nights                        2.100000e+01  3.500000e+01
# maximum_maximum_nights                        2.100000e+01  7.250000e+01
# minimum_nights_avg_ntm                        2.000000e+00  3.000000e+00
# maximum_nights_avg_ntm                        2.100000e+01  6.000000e+01
# calendar_updated                                       NaN           NaN
# availability_30                               0.000000e+00  0.000000e+00
# availability_60                               0.000000e+00  4.000000e+00
# availability_90                               0.000000e+00  8.000000e+00
# availability_365                              0.000000e+00  2.600000e+01
# number_of_reviews                             3.000000e+00  1.000000e+01
# number_of_reviews_ltm                         0.000000e+00  2.000000e+00
# number_of_reviews_l30d                        0.000000e+00  0.000000e+00
# availability_eoy                              0.000000e+00  1.400000e+01
# number_of_reviews_ly                          0.000000e+00  2.000000e+00
# estimated_occupancy_l365d                     0.000000e+00  1.600000e+01
# estimated_revenue_l365d                       2.088000e+03  7.560000e+03
# review_scores_rating                          4.790000e+00  4.920000e+00
# review_scores_accuracy                        4.800000e+00  4.920000e+00
# review_scores_cleanliness                     4.690000e+00  4.870000e+00
# review_scores_checkin                         4.860000e+00  4.970000e+00
# review_scores_communication                   4.900000e+00  5.000000e+00
# review_scores_location                        4.720000e+00  4.880000e+00
# review_scores_value                           4.520000e+00  4.710000e+00
# calculated_host_listings_count                1.000000e+00  1.000000e+00
# calculated_host_listings_count_entire_homes   1.000000e+00  1.000000e+00
# calculated_host_listings_count_private_rooms  0.000000e+00  0.000000e+00
# calculated_host_listings_count_shared_rooms   0.000000e+00  0.000000e+00
# reviews_per_month                             2.000000e-01  4.100000e-01
#
#                                                        75%           max
# id                                            1.053090e+18  1.438602e+18
# scrape_id                                     2.025061e+13  2.025061e+13
# host_id                                       1.829336e+08  6.996424e+08
# host_listings_count                           1.000000e+00  9.110000e+02
# host_total_listings_count                     2.000000e+00  1.621000e+03
# neighbourhood_group_cleansed                           NaN           NaN
# latitude                                      5.237645e+01  5.242512e+01
# longitude                                     4.908866e+00  5.026669e+00
# accommodates                                  4.000000e+00  1.600000e+01
# bathrooms                                     1.500000e+00  1.700000e+01
# bedrooms                                      2.000000e+00  1.700000e+01
# beds                                          2.000000e+00  3.300000e+01
# minimum_nights                                4.000000e+00  1.001000e+03
# maximum_nights                                3.650000e+02  1.125000e+03
# minimum_minimum_nights                        3.000000e+00  1.001000e+03
# maximum_minimum_nights                        4.000000e+00  1.001000e+03
# minimum_maximum_nights                        7.300000e+02  2.147484e+09
# maximum_maximum_nights                        9.990000e+02  2.147484e+09
# minimum_nights_avg_ntm                        4.000000e+00  1.001000e+03
# maximum_nights_avg_ntm                        8.457250e+02  2.147484e+09
# calendar_updated                                       NaN           NaN
# availability_30                               9.000000e+00  3.000000e+01
# availability_60                               2.300000e+01  6.000000e+01
# availability_90                               3.800000e+01  9.000000e+01
# availability_365                              1.670000e+02  3.650000e+02
# number_of_reviews                             3.100000e+01  4.792000e+03
# number_of_reviews_ltm                         6.000000e+00  8.480000e+02
# number_of_reviews_l30d                        1.000000e+00  8.500000e+01
# availability_eoy                              9.000000e+01  1.980000e+02
# number_of_reviews_ly                          6.000000e+00  8.360000e+02
# estimated_occupancy_l365d                     5.500000e+01  2.550000e+02
# estimated_revenue_l365d                       2.021200e+04  2.350000e+06
# review_scores_rating                          5.000000e+00  5.000000e+00
# review_scores_accuracy                        5.000000e+00  5.000000e+00
# review_scores_cleanliness                     5.000000e+00  5.000000e+00
# review_scores_checkin                         5.000000e+00  5.000000e+00
# review_scores_communication                   5.000000e+00  5.000000e+00
# review_scores_location                        5.000000e+00  5.000000e+00
# review_scores_value                           4.850000e+00  5.000000e+00
# calculated_host_listings_count                1.000000e+00  3.900000e+01
# calculated_host_listings_count_entire_homes   1.000000e+00  3.400000e+01
# calculated_host_listings_count_private_rooms  0.000000e+00  1.700000e+01
# calculated_host_listings_count_shared_rooms   0.000000e+00  9.000000e+00
# reviews_per_month                             9.200000e-01  9.901000e+01

# %% [markdown]
# ### 3.0 Identify and handle missing values

# %% [markdown]
# #### 3.1 Identify missing values

# %%
df.replace("?", np.nan, inplace = True)
df.replace(" ", np.nan, inplace = True)
df.replace("NULL", np.nan, inplace = True)
df.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  27886  https://www.airbnb.com/rooms/27886  20250609011745   2025-06-17
# 1  28871  https://www.airbnb.com/rooms/28871  20250609011745   2025-06-17
# 2  29051  https://www.airbnb.com/rooms/29051  20250609011745   2025-06-17
# 3  44391  https://www.airbnb.com/rooms/44391  20250609011745   2025-06-17
# 4  47061  https://www.airbnb.com/rooms/47061  20250609011745   2025-06-17
#
#             source                                               name  \
# 0      city scrape  Romantic, stylish B&B houseboat in canal district
# 1      city scrape                            Comfortable double room
# 2      city scrape                   Comfortable single / double room
# 3  previous scrape    Quiet 2-bedroom Amsterdam city centre apartment
# 4      city scrape                   Charming apartment in old centre
#
#                                          description  \
# 0  Stylish and romantic houseboat on fantastic hi...
# 1          Basic bedroom in the center of Amsterdam.
# 2  This room can also be rented as a single or a ...
# 3  Guests greatly appreciate the unique location ...
# 4  A beautiful, quiet apartment in the center of ...
#
#                                neighborhood_overview  \
# 0         Central, quiet, safe, clean and beautiful.
# 1       Flower market , Leidseplein , Rembrantsplein
# 2  the street is quite lively especially on weeke...
# 3  The appartment is located in the city centre. ...
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/02c2da9d-660e...    97647  ...
# 1  https://a0.muscache.com/pictures/160889/362340...   124245  ...
# 2  https://a0.muscache.com/pictures/162009/bd6be2...   124245  ...
# 3  https://a0.muscache.com/pictures/97741545/3900...   194779  ...
# 4  https://a0.muscache.com/pictures/268343/a08ce2...   211696  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.92                   4.90                4.78
# 1                        4.94                   4.94                4.84
# 2                        4.92                   4.87                4.79
# 3                        4.90                   4.68                4.50
# 4                        4.90                   4.85                4.63
#
#                     license instant_bookable calculated_host_listings_count  \
# 0  0363 974D 4986 7411 88D8                f                              1
# 1  0363 607B EA74 0BD8 2F6F                f                              2
# 2  0363 607B EA74 0BD8 2F6F                f                              2
# 3  0363 E76E F06A C1DD 172C                f                              1
# 4  0363 1266 8C04 4133 E6AC                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            2
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.85
# 1                                           0              3.93
# 2                                           0              4.74
# 3                                           0              0.23
# 4                                           0              1.13
#
# [5 rows x 79 columns]

# %% [markdown]
# #### 3.2 Evaluating for Missing Data

# %%
missing_data = df.isnull()
missing_data
# Out:
#           id  listing_url  scrape_id  last_scraped  source   name  \
# 0      False        False      False         False   False  False
# 1      False        False      False         False   False  False
# 2      False        False      False         False   False  False
# 3      False        False      False         False   False  False
# 4      False        False      False         False   False  False
# ...      ...          ...        ...           ...     ...    ...
# 10163  False        False      False         False   False  False
# 10164  False        False      False         False   False  False
# 10165  False        False      False         False   False  False
# 10166  False        False      False         False   False  False
# 10167  False        False      False         False   False  False
#
#        description  neighborhood_overview  picture_url  host_id  ...  \
# 0            False                  False        False    False  ...
# 1            False                  False        False    False  ...
# 2            False                  False        False    False  ...
# 3            False                  False        False    False  ...
# 4            False                   True        False    False  ...
# ...            ...                    ...          ...      ...  ...
# 10163        False                   True        False    False  ...
# 10164        False                   True        False    False  ...
# 10165        False                   True        False    False  ...
# 10166        False                   True        False    False  ...
# 10167        False                   True        False    False  ...
#
#        review_scores_communication  review_scores_location  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 10163                         True                    True
# 10164                         True                    True
# 10165                         True                    True
# 10166                         True                    True
# 10167                         True                    True
#
#        review_scores_value  license  instant_bookable  \
# 0                    False    False             False
# 1                    False    False             False
# 2                    False    False             False
# 3                    False    False             False
# 4                    False    False             False
# ...                    ...      ...               ...
# 10163                 True    False             False
# 10164                 True    False             False
# 10165                 True    False             False
# 10166                 True    False             False
# 10167                 True    False             False
#
#        calculated_host_listings_count  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ...                               ...
# 10163                           False
# 10164                           False
# 10165                           False
# 10166                           False
# 10167                           False
#
#        calculated_host_listings_count_entire_homes  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 10163                                        False
# 10164                                        False
# 10165                                        False
# 10166                                        False
# 10167                                        False
#
#        calculated_host_listings_count_private_rooms  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 10163                                         False
# 10164                                         False
# 10165                                         False
# 10166                                         False
# 10167                                         False
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            False              False
# 1                                            False              False
# 2                                            False              False
# 3                                            False              False
# 4                                            False              False
# ...                                            ...                ...
# 10163                                        False               True
# 10164                                        False               True
# 10165                                        False               True
# 10166                                        False               True
# 10167                                        False               True
#
# [10168 rows x 79 columns]

# %% [markdown]
# #### 3.3 Count missing values in each column

# %%
for column in missing_data.columns.values.tolist():
    print (missing_data[column].value_counts())
    print("")
# Out:
# id
# False    10168
# Name: count, dtype: int64
#
# listing_url
# False    10168
# Name: count, dtype: int64
#
# scrape_id
# False    10168
# Name: count, dtype: int64
#
# last_scraped
# False    10168
# Name: count, dtype: int64
#
# source
# False    10168
# Name: count, dtype: int64
#
# name
# False    10168
# Name: count, dtype: int64
#
# description
# False    9859
# True      309
# Name: count, dtype: int64
#
# neighborhood_overview
# False    5258
# True     4910
# Name: count, dtype: int64
#
# picture_url
# False    10168
# Name: count, dtype: int64
#
# host_id
# False    10168
# Name: count, dtype: int64
#
# host_url
# False    10168
# Name: count, dtype: int64
#
# host_name
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_since
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_location
# False    9024
# True     1144
# Name: count, dtype: int64
#
# host_about
# False    5366
# True     4802
# Name: count, dtype: int64
#
# host_response_time
# False    6640
# True     3528
# Name: count, dtype: int64
#
# host_response_rate
# False    6640
# True     3528
# Name: count, dtype: int64
#
# host_acceptance_rate
# False    7937
# True     2231
# Name: count, dtype: int64
#
# host_is_superhost
# False    10069
# True        99
# Name: count, dtype: int64
#
# host_thumbnail_url
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_picture_url
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_neighbourhood
# True     7354
# False    2814
# Name: count, dtype: int64
#
# host_listings_count
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_total_listings_count
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_verifications
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_has_profile_pic
# False    10164
# True         4
# Name: count, dtype: int64
#
# host_identity_verified
# False    10164
# True         4
# Name: count, dtype: int64
#
# neighbourhood
# False    5258
# True     4910
# Name: count, dtype: int64
#
# neighbourhood_cleansed
# False    10168
# Name: count, dtype: int64
#
# neighbourhood_group_cleansed
# True    10168
# Name: count, dtype: int64
#
# latitude
# False    10168
# Name: count, dtype: int64
#
# longitude
# False    10168
# Name: count, dtype: int64
#
# property_type
# False    10168
# Name: count, dtype: int64
#
# room_type
# False    10168
# Name: count, dtype: int64
#
# accommodates
# False    10168
# Name: count, dtype: int64
#
# bathrooms
# False    6377
# True     3791
# Name: count, dtype: int64
#
# bathrooms_text
# False    10162
# True         6
# Name: count, dtype: int64
#
# bedrooms
# False    9874
# True      294
# Name: count, dtype: int64
#
# beds
# False    6341
# True     3827
# Name: count, dtype: int64
#
# amenities
# False    10168
# Name: count, dtype: int64
#
# price
# False    6321
# True     3847
# Name: count, dtype: int64
#
# minimum_nights
# False    10168
# Name: count, dtype: int64
#
# maximum_nights
# False    10168
# Name: count, dtype: int64
#
# minimum_minimum_nights
# False    10168
# Name: count, dtype: int64
#
# maximum_minimum_nights
# False    10168
# Name: count, dtype: int64
#
# minimum_maximum_nights
# False    10168
# Name: count, dtype: int64
#
# maximum_maximum_nights
# False    10168
# Name: count, dtype: int64
#
# minimum_nights_avg_ntm
# False    10168
# Name: count, dtype: int64
#
# maximum_nights_avg_ntm
# False    10168
# Name: count, dtype: int64
#
# calendar_updated
# True    10168
# Name: count, dtype: int64
#
# has_availability
# False    9849
# True      319
# Name: count, dtype: int64
#
# availability_30
# False    10168
# Name: count, dtype: int64
#
# availability_60
# False    10168
# Name: count, dtype: int64
#
# availability_90
# False    10168
# Name: count, dtype: int64
#
# availability_365
# False    10168
# Name: count, dtype: int64
#
# calendar_last_scraped
# False    10168
# Name: count, dtype: int64
#
# number_of_reviews
# False    10168
# Name: count, dtype: int64
#
# number_of_reviews_ltm
# False    10168
# Name: count, dtype: int64
#
# number_of_reviews_l30d
# False    10168
# Name: count, dtype: int64
#
# availability_eoy
# False    10168
# Name: count, dtype: int64
#
# number_of_reviews_ly
# False    10168
# Name: count, dtype: int64
#
# estimated_occupancy_l365d
# False    10168
# Name: count, dtype: int64
#
# estimated_revenue_l365d
# False    6321
# True     3847
# Name: count, dtype: int64
#
# first_review
# False    9198
# True      970
# Name: count, dtype: int64
#
# last_review
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_rating
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_accuracy
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_cleanliness
# False    9197
# True      971
# Name: count, dtype: int64
#
# review_scores_checkin
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_communication
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_location
# False    9198
# True      970
# Name: count, dtype: int64
#
# review_scores_value
# False    9198
# True      970
# Name: count, dtype: int64
#
# license
# False    10062
# True       106
# Name: count, dtype: int64
#
# instant_bookable
# False    10168
# Name: count, dtype: int64
#
# calculated_host_listings_count
# False    10168
# Name: count, dtype: int64
#
# calculated_host_listings_count_entire_homes
# False    10168
# Name: count, dtype: int64
#
# calculated_host_listings_count_private_rooms
# False    10168
# Name: count, dtype: int64
#
# calculated_host_listings_count_shared_rooms
# False    10168
# Name: count, dtype: int64
#
# reviews_per_month
# False    9198
# True      970
# Name: count, dtype: int64

# %% [markdown]
# #### 3.4 Remove unneccessary culomns with missing values

# %%
columns_to_drop = [
    "listing_url", "scrape_id", "last_scraped", "source",
    "neighborhood_overview", "picture_url", "host_id", "host_url",
    "host_name", "host_since", "host_location", "host_about", "host_response_time",
    "host_thumbnail_url", "host_picture_url", "host_neighbourhood",
    "host_identity_verified", "neighbourhood_group_cleansed",
    "calendar_updated", "has_availability", "availability_30", "availability_60",
    "availability_90", "availability_365", "calendar_last_scraped",
    "availability_eoy", "estimated_occupancy_l365d", "first_review", "last_review",
    "license", "calculated_host_listings_count",
    "calculated_host_listings_count_entire_homes",
    "calculated_host_listings_count_private_rooms",
    "calculated_host_listings_count_shared_rooms",
    "estimated_revenue_l365d", "reviews_per_month",
    "host_verifications", "latitude", "longitude",
]

df.drop(columns=columns_to_drop, errors="ignore", inplace=True)
df.head()
# Out:
#       id                                               name  \
# 0  27886  Romantic, stylish B&B houseboat in canal district
# 1  28871                            Comfortable double room
# 2  29051                   Comfortable single / double room
# 3  44391    Quiet 2-bedroom Amsterdam city centre apartment
# 4  47061                   Charming apartment in old centre
#
#                                          description host_response_rate  \
# 0  Stylish and romantic houseboat on fantastic hi...               100%
# 1          Basic bedroom in the center of Amsterdam.               100%
# 2  This room can also be rented as a single or a ...               100%
# 3  Guests greatly appreciate the unique location ...                NaN
# 4  A beautiful, quiet apartment in the center of ...               100%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  98%                 t                  1.0
# 1                  99%                 t                  2.0
# 2                  99%                 t                  2.0
# 3                  NaN                 f                  1.0
# 4                  50%                 f                  1.0
#
#    host_total_listings_count host_has_profile_pic  \
# 0                        1.0                    t
# 1                        2.0                    t
# 2                        2.0                    t
# 3                        1.0                    t
# 4                        2.0                    t
#
#                            neighbourhood  ... number_of_reviews_l30d  \
# 0  Amsterdam, North Holland, Netherlands  ...                      1
# 1  Amsterdam, North Holland, Netherlands  ...                      9
# 2  Amsterdam, North Holland, Netherlands  ...                      7
# 3  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 4                                    NaN  ...                      1
#
#   number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                   26                 4.92                    4.90
# 1                   96                 4.88                    4.90
# 2                   88                 4.81                    4.88
# 3                    0                 4.71                    4.68
# 4                    6                 4.77                    4.78
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.94                  4.95
# 1                       4.87                  4.94
# 2                       4.83                  4.93
# 3                       4.49                  4.95
# 4                       4.61                  4.76
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.92                    4.90                4.78
# 1                         4.94                    4.94                4.84
# 2                         4.92                    4.87                4.79
# 3                         4.90                    4.68                4.50
# 4                         4.90                    4.85                4.63
#
#   instant_bookable
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
#
# [5 rows x 40 columns]

# %% [markdown]
# #### 3.6 Replace missing value freqency

# %%
mode_columns = [
    'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type'
]

for col in mode_columns:
    if col in df.columns and not df[col].mode().empty:
        df[col] = df[col].fillna(df[col].mode()[0])

df.head(10)
# Out:
#       id                                               name  \
# 0  27886  Romantic, stylish B&B houseboat in canal district
# 1  28871                            Comfortable double room
# 2  29051                   Comfortable single / double room
# 3  44391    Quiet 2-bedroom Amsterdam city centre apartment
# 4  47061                   Charming apartment in old centre
# 5  48373                Cozy family home in Amsterdam South
# 6  49552       Multatuli Luxury Guest Suite in top location
# 7  50263         Central de Lux 2 bedrooms (4p) apt 125 sqm
# 8  50515         Family Home (No drugs, smoking or parties)
# 9  50523                 B & B de 9 Straatjes (city center)
#
#                                          description host_response_rate  \
# 0  Stylish and romantic houseboat on fantastic hi...               100%
# 1          Basic bedroom in the center of Amsterdam.               100%
# 2  This room can also be rented as a single or a ...               100%
# 3  Guests greatly appreciate the unique location ...               100%
# 4  A beautiful, quiet apartment in the center of ...               100%
# 5  Charming modern apartment in the quiet and gre...               100%
# 6  Stylish & spacious 60m2 guest suite in Amsterd...               100%
# 7  A beautiful 'De Lux' 125 sqm apartment for 4 a...               100%
# 8  This is a beautiful family home in a lovely pa...               100%
# 9  B&B “De 9 Straatjes” – Your home in the heart ...                90%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  98%                 t                  1.0
# 1                  99%                 t                  2.0
# 2                  99%                 t                  2.0
# 3                 100%                 f                  1.0
# 4                  50%                 f                  1.0
# 5                 100%                 f                  1.0
# 6                  92%                 t                  1.0
# 7                  91%                 f                  1.0
# 8                  21%                 f                  1.0
# 9                  99%                 t                  1.0
#
#    host_total_listings_count host_has_profile_pic  \
# 0                        1.0                    t
# 1                        2.0                    t
# 2                        2.0                    t
# 3                        1.0                    t
# 4                        2.0                    t
# 5                        1.0                    t
# 6                        2.0                    t
# 7                        1.0                    t
# 8                        1.0                    t
# 9                        1.0                    t
#
#                            neighbourhood  ... number_of_reviews_l30d  \
# 0  Amsterdam, North Holland, Netherlands  ...                      1
# 1  Amsterdam, North Holland, Netherlands  ...                      9
# 2  Amsterdam, North Holland, Netherlands  ...                      7
# 3  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 4  Amsterdam, Noord-Holland, Netherlands  ...                      1
# 5  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 6  Amsterdam, North Holland, Netherlands  ...                      8
# 7  Amsterdam, North Holland, Netherlands  ...                      2
# 8  Amsterdam, North Holland, Netherlands  ...                      0
# 9  Amsterdam, Noord-Holland, Netherlands  ...                      5
#
#   number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                   26                 4.92                    4.90
# 1                   96                 4.88                    4.90
# 2                   88                 4.81                    4.88
# 3                    0                 4.71                    4.68
# 4                    6                 4.77                    4.78
# 5                    3                 5.00                    5.00
# 6                   58                 4.93                    4.93
# 7                    7                 4.85                    4.91
# 8                    5                 4.78                    4.83
# 9                   68                 4.88                    4.90
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.94                  4.95
# 1                       4.87                  4.94
# 2                       4.83                  4.93
# 3                       4.49                  4.95
# 4                       4.61                  4.76
# 5                       5.00                  5.00
# 6                       4.93                  4.96
# 7                       4.81                  4.82
# 8                       4.83                  4.83
# 9                       4.83                  4.86
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.92                    4.90                4.78
# 1                         4.94                    4.94                4.84
# 2                         4.92                    4.87                4.79
# 3                         4.90                    4.68                4.50
# 4                         4.90                    4.85                4.63
# 5                         5.00                    4.60                5.00
# 6                         4.97                    4.98                4.78
# 7                         4.76                    4.65                4.74
# 8                         4.89                    4.56                4.78
# 9                         4.83                    4.94                4.83
#
#   instant_bookable
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
# 5                f
# 6                f
# 7                f
# 8                f
# 9                f
#
# [10 rows x 40 columns]

# %% [markdown]
# #### 3.7 Replace missing value with mean

# %%
mean_columns = [
    'review_scores_value', 'review_scores_location', 'review_scores_rating',
    'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin',
    'review_scores_communication'
]

for col in mean_columns:
    if col in df.columns:
        df[col] = df[col].fillna(df[col].mean())

df.head(10)
# Out:
#       id                                               name  \
# 0  27886  Romantic, stylish B&B houseboat in canal district
# 1  28871                            Comfortable double room
# 2  29051                   Comfortable single / double room
# 3  44391    Quiet 2-bedroom Amsterdam city centre apartment
# 4  47061                   Charming apartment in old centre
# 5  48373                Cozy family home in Amsterdam South
# 6  49552       Multatuli Luxury Guest Suite in top location
# 7  50263         Central de Lux 2 bedrooms (4p) apt 125 sqm
# 8  50515         Family Home (No drugs, smoking or parties)
# 9  50523                 B & B de 9 Straatjes (city center)
#
#                                          description host_response_rate  \
# 0  Stylish and romantic houseboat on fantastic hi...               100%
# 1          Basic bedroom in the center of Amsterdam.               100%
# 2  This room can also be rented as a single or a ...               100%
# 3  Guests greatly appreciate the unique location ...               100%
# 4  A beautiful, quiet apartment in the center of ...               100%
# 5  Charming modern apartment in the quiet and gre...               100%
# 6  Stylish & spacious 60m2 guest suite in Amsterd...               100%
# 7  A beautiful 'De Lux' 125 sqm apartment for 4 a...               100%
# 8  This is a beautiful family home in a lovely pa...               100%
# 9  B&B “De 9 Straatjes” – Your home in the heart ...                90%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  98%                 t                  1.0
# 1                  99%                 t                  2.0
# 2                  99%                 t                  2.0
# 3                 100%                 f                  1.0
# 4                  50%                 f                  1.0
# 5                 100%                 f                  1.0
# 6                  92%                 t                  1.0
# 7                  91%                 f                  1.0
# 8                  21%                 f                  1.0
# 9                  99%                 t                  1.0
#
#    host_total_listings_count host_has_profile_pic  \
# 0                        1.0                    t
# 1                        2.0                    t
# 2                        2.0                    t
# 3                        1.0                    t
# 4                        2.0                    t
# 5                        1.0                    t
# 6                        2.0                    t
# 7                        1.0                    t
# 8                        1.0                    t
# 9                        1.0                    t
#
#                            neighbourhood  ... number_of_reviews_l30d  \
# 0  Amsterdam, North Holland, Netherlands  ...                      1
# 1  Amsterdam, North Holland, Netherlands  ...                      9
# 2  Amsterdam, North Holland, Netherlands  ...                      7
# 3  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 4  Amsterdam, Noord-Holland, Netherlands  ...                      1
# 5  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 6  Amsterdam, North Holland, Netherlands  ...                      8
# 7  Amsterdam, North Holland, Netherlands  ...                      2
# 8  Amsterdam, North Holland, Netherlands  ...                      0
# 9  Amsterdam, Noord-Holland, Netherlands  ...                      5
#
#   number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                   26                 4.92                    4.90
# 1                   96                 4.88                    4.90
# 2                   88                 4.81                    4.88
# 3                    0                 4.71                    4.68
# 4                    6                 4.77                    4.78
# 5                    3                 5.00                    5.00
# 6                   58                 4.93                    4.93
# 7                    7                 4.85                    4.91
# 8                    5                 4.78                    4.83
# 9                   68                 4.88                    4.90
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.94                  4.95
# 1                       4.87                  4.94
# 2                       4.83                  4.93
# 3                       4.49                  4.95
# 4                       4.61                  4.76
# 5                       5.00                  5.00
# 6                       4.93                  4.96
# 7                       4.81                  4.82
# 8                       4.83                  4.83
# 9                       4.83                  4.86
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.92                    4.90                4.78
# 1                         4.94                    4.94                4.84
# 2                         4.92                    4.87                4.79
# 3                         4.90                    4.68                4.50
# 4                         4.90                    4.85                4.63
# 5                         5.00                    4.60                5.00
# 6                         4.97                    4.98                4.78
# 7                         4.76                    4.65                4.74
# 8                         4.89                    4.56                4.78
# 9                         4.83                    4.94                4.83
#
#   instant_bookable
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
# 5                f
# 6                f
# 7                f
# 8                f
# 9                f
#
# [10 rows x 40 columns]

# %% [markdown]
# #### 3.8 Replace missing value with random object

# %%
if 'host_response_rate' in df.columns and not df['host_response_rate'].mode().empty:
    df['host_response_rate'] = df['host_response_rate'].fillna(df['host_response_rate'].mode()[0])

df.head(10)
# Out:
#       id                                               name  \
# 0  27886  Romantic, stylish B&B houseboat in canal district
# 1  28871                            Comfortable double room
# 2  29051                   Comfortable single / double room
# 3  44391    Quiet 2-bedroom Amsterdam city centre apartment
# 4  47061                   Charming apartment in old centre
# 5  48373                Cozy family home in Amsterdam South
# 6  49552       Multatuli Luxury Guest Suite in top location
# 7  50263         Central de Lux 2 bedrooms (4p) apt 125 sqm
# 8  50515         Family Home (No drugs, smoking or parties)
# 9  50523                 B & B de 9 Straatjes (city center)
#
#                                          description host_response_rate  \
# 0  Stylish and romantic houseboat on fantastic hi...               100%
# 1          Basic bedroom in the center of Amsterdam.               100%
# 2  This room can also be rented as a single or a ...               100%
# 3  Guests greatly appreciate the unique location ...               100%
# 4  A beautiful, quiet apartment in the center of ...               100%
# 5  Charming modern apartment in the quiet and gre...               100%
# 6  Stylish & spacious 60m2 guest suite in Amsterd...               100%
# 7  A beautiful 'De Lux' 125 sqm apartment for 4 a...               100%
# 8  This is a beautiful family home in a lovely pa...               100%
# 9  B&B “De 9 Straatjes” – Your home in the heart ...                90%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  98%                 t                  1.0
# 1                  99%                 t                  2.0
# 2                  99%                 t                  2.0
# 3                 100%                 f                  1.0
# 4                  50%                 f                  1.0
# 5                 100%                 f                  1.0
# 6                  92%                 t                  1.0
# 7                  91%                 f                  1.0
# 8                  21%                 f                  1.0
# 9                  99%                 t                  1.0
#
#    host_total_listings_count host_has_profile_pic  \
# 0                        1.0                    t
# 1                        2.0                    t
# 2                        2.0                    t
# 3                        1.0                    t
# 4                        2.0                    t
# 5                        1.0                    t
# 6                        2.0                    t
# 7                        1.0                    t
# 8                        1.0                    t
# 9                        1.0                    t
#
#                            neighbourhood  ... number_of_reviews_l30d  \
# 0  Amsterdam, North Holland, Netherlands  ...                      1
# 1  Amsterdam, North Holland, Netherlands  ...                      9
# 2  Amsterdam, North Holland, Netherlands  ...                      7
# 3  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 4  Amsterdam, Noord-Holland, Netherlands  ...                      1
# 5  Amsterdam, Noord-Holland, Netherlands  ...                      0
# 6  Amsterdam, North Holland, Netherlands  ...                      8
# 7  Amsterdam, North Holland, Netherlands  ...                      2
# 8  Amsterdam, North Holland, Netherlands  ...                      0
# 9  Amsterdam, Noord-Holland, Netherlands  ...                      5
#
#   number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                   26                 4.92                    4.90
# 1                   96                 4.88                    4.90
# 2                   88                 4.81                    4.88
# 3                    0                 4.71                    4.68
# 4                    6                 4.77                    4.78
# 5                    3                 5.00                    5.00
# 6                   58                 4.93                    4.93
# 7                    7                 4.85                    4.91
# 8                    5                 4.78                    4.83
# 9                   68                 4.88                    4.90
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.94                  4.95
# 1                       4.87                  4.94
# 2                       4.83                  4.93
# 3                       4.49                  4.95
# 4                       4.61                  4.76
# 5                       5.00                  5.00
# 6                       4.93                  4.96
# 7                       4.81                  4.82
# 8                       4.83                  4.83
# 9                       4.83                  4.86
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.92                    4.90                4.78
# 1                         4.94                    4.94                4.84
# 2                         4.92                    4.87                4.79
# 3                         4.90                    4.68                4.50
# 4                         4.90                    4.85                4.63
# 5                         5.00                    4.60                5.00
# 6                         4.97                    4.98                4.78
# 7                         4.76                    4.65                4.74
# 8                         4.89                    4.56                4.78
# 9                         4.83                    4.94                4.83
#
#   instant_bookable
# 0                f
# 1                f
# 2                f
# 3                f
# 4                f
# 5                f
# 6                f
# 7                f
# 8                f
# 9                f
#
# [10 rows x 40 columns]

# %% [markdown]
# #### 3.9 Drop rows with missing value

# %%
essential_columns = [
    'description','price', 'neighbourhood', 'neighbourhood_cleansed', 'property_type',
    'bathrooms_text', 'host_has_profile_pic', 'bedrooms', 'beds'
]

for col in essential_columns:
    if col in df.columns:
        df = df.dropna(subset=[col])

df.head(10)
# Out:
#        id                                               name  \
# 0   27886  Romantic, stylish B&B houseboat in canal district
# 1   28871                            Comfortable double room
# 2   29051                   Comfortable single / double room
# 4   47061                   Charming apartment in old centre
# 6   49552       Multatuli Luxury Guest Suite in top location
# 7   50263         Central de Lux 2 bedrooms (4p) apt 125 sqm
# 8   50515         Family Home (No drugs, smoking or parties)
# 9   50523                 B & B de 9 Straatjes (city center)
# 13  62015                Charming, beautifully & sunny place
# 16  97221                        Beautiful and spacious room
#
#                                           description host_response_rate  \
# 0   Stylish and romantic houseboat on fantastic hi...               100%
# 1           Basic bedroom in the center of Amsterdam.               100%
# 2   This room can also be rented as a single or a ...               100%
# 4   A beautiful, quiet apartment in the center of ...               100%
# 6   Stylish & spacious 60m2 guest suite in Amsterd...               100%
# 7   A beautiful 'De Lux' 125 sqm apartment for 4 a...               100%
# 8   This is a beautiful family home in a lovely pa...               100%
# 9   B&B “De 9 Straatjes” – Your home in the heart ...                90%
# 13  This beautiful apartment in one of the most li...               100%
# 16  Private room offered in elegant furnished, cle...               100%
#
#    host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                   98%                 t                  1.0
# 1                   99%                 t                  2.0
# 2                   99%                 t                  2.0
# 4                   50%                 f                  1.0
# 6                   92%                 t                  1.0
# 7                   91%                 f                  1.0
# 8                   21%                 f                  1.0
# 9                   99%                 t                  1.0
# 13                   0%                 f                  1.0
# 16                  98%                 f                  2.0
#
#     host_total_listings_count host_has_profile_pic  \
# 0                         1.0                    t
# 1                         2.0                    t
# 2                         2.0                    t
# 4                         2.0                    t
# 6                         2.0                    t
# 7                         1.0                    t
# 8                         1.0                    t
# 9                         1.0                    t
# 13                        1.0                    t
# 16                        2.0                    t
#
#                             neighbourhood  ... number_of_reviews_l30d  \
# 0   Amsterdam, North Holland, Netherlands  ...                      1
# 1   Amsterdam, North Holland, Netherlands  ...                      9
# 2   Amsterdam, North Holland, Netherlands  ...                      7
# 4   Amsterdam, Noord-Holland, Netherlands  ...                      1
# 6   Amsterdam, North Holland, Netherlands  ...                      8
# 7   Amsterdam, North Holland, Netherlands  ...                      2
# 8   Amsterdam, North Holland, Netherlands  ...                      0
# 9   Amsterdam, Noord-Holland, Netherlands  ...                      5
# 13  Amsterdam, North Holland, Netherlands  ...                      0
# 16  Amsterdam, Noord-Holland, Netherlands  ...                      3
#
#    number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                    26                 4.92                    4.90
# 1                    96                 4.88                    4.90
# 2                    88                 4.81                    4.88
# 4                     6                 4.77                    4.78
# 6                    58                 4.93                    4.93
# 7                     7                 4.85                    4.91
# 8                     5                 4.78                    4.83
# 9                    68                 4.88                    4.90
# 13                    3                 4.89                    4.92
# 16                   66                 4.68                    4.74
#
#     review_scores_cleanliness review_scores_checkin  \
# 0                        4.94                  4.95
# 1                        4.87                  4.94
# 2                        4.83                  4.93
# 4                        4.61                  4.76
# 6                        4.93                  4.96
# 7                        4.81                  4.82
# 8                        4.83                  4.83
# 9                        4.83                  4.86
# 13                       4.89                  5.00
# 16                       4.89                  4.72
#
#     review_scores_communication  review_scores_location review_scores_value  \
# 0                          4.92                    4.90                4.78
# 1                          4.94                    4.94                4.84
# 2                          4.92                    4.87                4.79
# 4                          4.90                    4.85                4.63
# 6                          4.97                    4.98                4.78
# 7                          4.76                    4.65                4.74
# 8                          4.89                    4.56                4.78
# 9                          4.83                    4.94                4.83
# 13                         4.89                    4.65                4.57
# 16                         4.78                    4.46                4.56
#
#    instant_bookable
# 0                 f
# 1                 f
# 2                 f
# 4                 f
# 6                 f
# 7                 f
# 8                 f
# 9                 f
# 13                f
# 16                f
#
# [10 rows x 40 columns]

# %% [markdown]
# ### 3.9 Remove dollar sign from price culmn

# %%
df['price'] = (
    df['price']
    .replace(r'[\$,]', '', regex=True)
    .astype(float)
)

df.head()
# Out:
#       id                                               name  \
# 0  27886  Romantic, stylish B&B houseboat in canal district
# 1  28871                            Comfortable double room
# 2  29051                   Comfortable single / double room
# 4  47061                   Charming apartment in old centre
# 6  49552       Multatuli Luxury Guest Suite in top location
#
#                                          description host_response_rate  \
# 0  Stylish and romantic houseboat on fantastic hi...               100%
# 1          Basic bedroom in the center of Amsterdam.               100%
# 2  This room can also be rented as a single or a ...               100%
# 4  A beautiful, quiet apartment in the center of ...               100%
# 6  Stylish & spacious 60m2 guest suite in Amsterd...               100%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  98%                 t                  1.0
# 1                  99%                 t                  2.0
# 2                  99%                 t                  2.0
# 4                  50%                 f                  1.0
# 6                  92%                 t                  1.0
#
#    host_total_listings_count host_has_profile_pic  \
# 0                        1.0                    t
# 1                        2.0                    t
# 2                        2.0                    t
# 4                        2.0                    t
# 6                        2.0                    t
#
#                            neighbourhood  ... number_of_reviews_l30d  \
# 0  Amsterdam, North Holland, Netherlands  ...                      1
# 1  Amsterdam, North Holland, Netherlands  ...                      9
# 2  Amsterdam, North Holland, Netherlands  ...                      7
# 4  Amsterdam, Noord-Holland, Netherlands  ...                      1
# 6  Amsterdam, North Holland, Netherlands  ...                      8
#
#   number_of_reviews_ly review_scores_rating  review_scores_accuracy  \
# 0                   26                 4.92                    4.90
# 1                   96                 4.88                    4.90
# 2                   88                 4.81                    4.88
# 4                    6                 4.77                    4.78
# 6                   58                 4.93                    4.93
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.94                  4.95
# 1                       4.87                  4.94
# 2                       4.83                  4.93
# 4                       4.61                  4.76
# 6                       4.93                  4.96
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         4.92                    4.90                4.78
# 1                         4.94                    4.94                4.84
# 2                         4.92                    4.87                4.79
# 4                         4.90                    4.85                4.63
# 6                         4.97                    4.98                4.78
#
#    instant_bookable
# 0                 f
# 1                 f
# 2                 f
# 4                 f
# 6                 f
#
# [5 rows x 40 columns]

# %% [markdown]
# ### 4.0 Searching for and removing duplicates

# %%
duplicate_rows = df[df.duplicated(keep=False)]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ### 5.0 Save cleaned data

# %% [markdown]
# #### 5.1 Save to csv

# %%
CLEAN_CSV_PATH = "../data/cleaned/amsterdam_airbnbs_clean_data.csv"
df.to_csv(CLEAN_CSV_PATH, index=False)
print(f"Cleaned data saved to CSV: {CLEAN_CSV_PATH}")
# Out:
# Cleaned data saved to CSV: ../data/cleaned/amsterdam_airbnbs_clean_data.csv

# %% [markdown]
# #### 5.2 Save to sql database

# %%
config = DatabaseConfig()
db = DatabaseConnection(config)

TABLE_NAME = "amsterdam_airbnbs_clean_data"

db.write_dataframe(df, TABLE_NAME, if_exists="replace")
# Out:
# DataFrame successfully saved to table: amsterdam_airbnbs_clean_data
